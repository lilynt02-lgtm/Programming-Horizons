# %% [markdown]
# <a href="https://colab.research.google.com/github/lilynt02-lgtm/Programming-Horizons/blob/main/Employees_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/Employees.csv')

# %%
#display the first 5 rows of the dataframe = head(). We can input the number of rows that we want to display
print(df.head(10))
# Out:
#    EmpID     Name     City  Age   Salary Department
# 0    101    Alice   London   32  50000.0         HR
# 1    102      Bob    Paris   31  60000.0    Finance
# 2    103    Chris  NewYork   35  40000.0        DBA
# 3    104    David   London   37      NaN         IT
# 4    105    Emily    Paris   33  55000.0         HR
# 5    106     Gina    Paris   34      NaN         IT
# 6    107  Charlie   Boston   29  45000.0        NaN
# 7    108     Paul   Sydney   30  50000.0        DBA

# %%
#display the last 5 rows = tail()
print(df.tail())
# Out:
#    EmpID     Name    City  Age   Salary Department
# 3    104    David  London   37      NaN         IT
# 4    105    Emily   Paris   33  55000.0         HR
# 5    106     Gina   Paris   34      NaN         IT
# 6    107  Charlie  Boston   29  45000.0        NaN
# 7    108     Paul  Sydney   30  50000.0        DBA

# %%
#shape : how bis is this dataframe
print(df.shape)
#so here we have 8 rows and 6 columns in this dataframe
# Out:
# (8, 6)

# %%
#info() : exploring the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmpID       8 non-null      int64
#  1   Name        8 non-null      object
#  2   City        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Salary      6 non-null      float64
#  5   Department  7 non-null      object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 516.0+ bytes
# None

# %%
#describe() : display statistical summerises
print(df.describe)
# Out:
# <bound method NDFrame.describe of    EmpID     Name     City  Age   Salary Department
# 0    101    Alice   London   32  50000.0         HR
# 1    102      Bob    Paris   31  60000.0    Finance
# 2    103    Chris  NewYork   35  40000.0        DBA
# 3    104    David   London   37      NaN         IT
# 4    105    Emily    Paris   33  55000.0         HR
# 5    106     Gina    Paris   34      NaN         IT
# 6    107  Charlie   Boston   29  45000.0        NaN
# 7    108     Paul   Sydney   30  50000.0        DBA>
